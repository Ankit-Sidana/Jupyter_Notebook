# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("D:/PYTHON/titanic_dataset.csv")

# %%
print("First 5 records :")
data.head()
# Out:
# First 5 records :
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print("Last 5 records :")
data.tail()
# Out:
# Last 5 records :
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
dat_typ = data.dtypes
print("Column wise Data types :")
dat_typ
# Out:
# Column wise Data types :
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Aternatively
print("Column wise Data types :")
data.dtypes
# Out:
# Column wise Data types :
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
nt_null_ct = data.count()
print("Column wise non-null value count :")
nt_null_ct
# Out:
# Column wise non-null value count :
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
#Aternatively
print("Column wise non-null value count :")
data.count()
# Out:
# Column wise non-null value count :
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
ind = data.set_index('PassengerId',append = 'true', drop = 'false')
print("Index appended :")
ind
# Out:
# Index appended :
#                  Survived  Pclass  \
#     PassengerId
# 0   1                   0       3
# 1   2                   1       1
# 2   3                   1       3
# 3   4                   1       1
# 4   5                   0       3
# ...                   ...     ...
# 886 887                 0       2
# 887 888                 1       1
# 888 889                 0       3
# 889 890                 1       1
# 890 891                 0       3
#
#                                                               Name     Sex  \
#     PassengerId
# 0   1                                      Braund, Mr. Owen Harris    male
# 1   2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2   3                                       Heikkinen, Miss. Laina  female
# 3   4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4   5                                     Allen, Mr. William Henry    male
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
x = data['Age'].idxmin()
x

data.loc[x]
# Out:
# PassengerId                                804
# Survived                                     1
# Pclass                                       3
# Name           Thomas, Master. Assad Alexander
# Sex                                       male
# Age                                       0.42
# SibSp                                        0
# Parch                                        1
# Ticket                                    2625
# Fare                                    8.5167
# Cabin                                      NaN
# Embarked                                     C
# Name: 803, dtype: object

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("Number of unique values in Survived column is :", data.Survived.nunique())

print("Number of unique values in Pclass column is :", data.Pclass.nunique())

print("Number of unique values in Sex column is :", data.Sex.nunique())

print("Number of unique values in SibSp column is :", data.SibSp.nunique())

print("Number of unique values in Parch column is :", data.Parch.nunique())

print("Number of unique values in Embarked column is :", data.Embarked.nunique())
# Out:
# Number of unique values in Survived column is : 2
# Number of unique values in Pclass column is : 3
# Number of unique values in Sex column is : 2
# Number of unique values in SibSp column is : 7
# Number of unique values in Parch column is : 7
# Number of unique values in Embarked column is : 3

# %%
data1 = data.copy()

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.set_theme(style="darkgrid")

# %%
sns.displot(data = data1, x = "PassengerId" , y= "Age", kind = "kde")

# %%
sns.jointplot(data = data1, x = "PassengerId" , y= "Age", kind = "hex")

# %%
a = sns.barplot(data = data1, x = "Pclass", y = "Age", hue = 'Survived')

# %%
b = sns.countplot(data = data1 , x = "Sex", hue = "Embarked")

# %%
c = sns.boxplot(data = data1 , x="Pclass", y="Age", hue = "Survived")
#

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1["Age"]=data1.groupby('Pclass')['Age'].apply(lambda x: x.fillna(x.mean()))

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male  22.00000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00000
# 2                               Heikkinen, Miss. Laina  female  26.00000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00000
# 4                             Allen, Mr. William Henry    male  35.00000
# ..                                                 ...     ...       ...
# ...

# %%
dat = data[['Embarked','Name','Fare','Survived']]

dat.nlargest(10,['Fare'])
# Out:
#     Embarked                                   Name      Fare  Survived
# 258        C                       Ward, Miss. Anna  512.3292         1
# 679        C     Cardeza, Mr. Thomas Drake Martinez  512.3292         1
# 737        C                 Lesurer, Mr. Gustave J  512.3292         1
# 27         S         Fortune, Mr. Charles Alexander  263.0000         0
# 88         S             Fortune, Miss. Mabel Helen  263.0000         1
# 341        S         Fortune, Miss. Alice Elizabeth  263.0000         1
# 438        S                      Fortune, Mr. Mark  263.0000         0
# 311        C             Ryerson, Miss. Emily Borie  262.3750         1
# 742        C  Ryerson, Miss. Susan Parker "Suzette"  262.3750         1
# 118        C               Baxter, Mr. Quigg Edmond  247.5208         0

# %%
dumm = data[['Sex','Embarked']]
dum = pd.get_dummies(dumm,drop_first = True)
dum
# Out:
#      Sex_male  Embarked_Q  Embarked_S
# 0           1           0           1
# 1           0           0           0
# 2           0           0           1
# 3           0           0           1
# 4           1           0           1
# ..        ...         ...         ...
# 886         1           0           1
# 887         0           0           1
# 888         0           0           1
# 889         1           0           0
# 890         1           1           0
#
# [891 rows x 3 columns]

# %%
data = pd.concat([data, dum], axis =1)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop(['Sex','Embarked'],inplace=True,axis=1)
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
# 5                                   Moran, Mr. James   NaN      0      0
# 6                            McCarthy, Mr. Timothy J  54.0      0      0
# ...
